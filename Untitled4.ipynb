# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
v=iris.plot(title='iris plot',figsize=(10,10))

# %%
df=iris.drop(['species'],axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0].plot(kind='bar')

# %%
v.setxlabel='x axis'
v.setylabel='y axis'
v

# %%
iris.plot()

# %%
iris.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F71DFB9370>,
# ...
#       dtype=object)

# %%
iris.plot.hist()

# %%
iris['sepal_width'].plot.hist()

# %%
iris.plot(kind='hist',stacked='False',bins=100)

# %%
iris['sepal_width'].plot(kind='hist',bins=100,stacked='false')

# %%
x=iris[iris['sepal_width']==3.0]

# %%
len(x)
# Out:
# 26

# %%
y=iris['sepal_length']

# %%
y.diff().hist(color='r',figsize=(10,10),alpha=0.3)

# %%
#scatterplot
iris.plot.scatter(x="sepal_length",y="sepal_width")

# %%
iris.plot(kind='hexbin',x="sepal_length",y="sepal_width",C="petal_length",gridsize=20)

# %%
iris.plot.scatter(x="sepal_length",y="sepal_width",c="petal_length")

# %%
z=iris.drop(['species'],axis=1)

# %%
d=z.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
z.iloc[1]
# Out:
# sepal_length    4.9
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.2
# Name: 1, dtype: float64

# %%
z.iloc[1].plot(kind='bar')

# %%
d.plot.pie(figsize=(5,10))

# %%
g=z.iloc[0:3]

# %%
g.plot.pie(subplots='True',figsize=(15,5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F7213C9520>,
# ...
#       dtype=object)
